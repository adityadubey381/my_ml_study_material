# %%
from sklearn.datasets import make_regression
import numpy as np

# %%
X,y = make_regression(n_samples=4, n_features=1, n_informative=1, n_targets=1, noise=80, random_state=13)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(X,y)

# %%
#Lets apply OLS
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()
reg.fit(X,y)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([78.35063668])

# %%
reg.coef_
# Out:
# array([78.35063668])

# %%
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='red')

# %% [markdown]
# **Lets apply Gradient Descent slope is constant m = 78.35**
# **and lets assume the starting value for intercept b = 0**

# %%
y_pred = ((78.35 * X) + 0).reshape(4)

# %%
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color = 'red', label='OLS')
plt.plot(X,y_pred,color = 'green', label =' b = 0')
plt.legend()
plt.show()

# %%
m = 78.35
b = 0

loss_slope = -2 * np.sum(y - m*X.ravel() - b)
loss_slope
# Out:
# -209.27763408209216

# %%
#Lets make learning rate = 0.1
lr = 0.1

step_size = loss_slope*lr
step_size
# Out:
# -20.927763408209216

# %%
#Lets Calulating the B
b = b - step_size
b
# Out:
# 20.927763408209216

# %%
y_pred1 = ((78.35* X) +b).reshape(4)

# %%
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color = 'red',label = 'OLS')
plt.plot(X,y_pred1,color = '#00a65a',label = 'b = {}'.format(b))
plt.plot(X,y_pred,color = '#A3E4D7', label = 'b = 0')
plt.legend()
plt.show()

# %%
#Iteration 2

loss_slope = -2 * np.sum(y - m*X.ravel() - b)
loss_slope
# Out:
# -41.85552681641843

# %%
step_size = loss_slope*lr
step_size
# Out:
# -4.185552681641844

# %%
b = b - step_size
b
# Out:
# 25.11331608985106

# %%
y_pred2 = ((78.35 * X) +b).reshape(4)

# %%
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color = 'red', label = 'OLS')
plt.plot(X,y_pred2,color = '#00a65a', label = 'b = {}'.format(b))
plt.plot(X,y_pred1,color = '#A3E4D7',label = 'b = {}'.format(b))
plt.plot(X,y_pred,color = '#A3E4D7',label = 'b = 0')
plt.legend()
plt.show()

# %%
#Iteration 3
loss_slope = -2 * np.sum(y - m*X.ravel() - b)
loss_slope
# Out:
# -8.371105363283675

# %%
step_size =  loss_slope * lr
step_size
# Out:
# -0.8371105363283675

# %%
b = b - step_size
b
# Out:
# 25.95042662617943

# %%
y_pred3 = ((78.35 * X) +b).reshape(4)

# %%
plt.figure(figsize=(15,15))
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color = 'red', label = 'OLS')
plt.plot(X,y_pred3,color = '#00a65a', label = 'b = {}'.format(b))
plt.plot(X,y_pred2,color = '#A3E4D7', label = 'b = {}'.format(b))
plt.plot(X,y_pred1,color = '#A3E4D7', label = 'b = {}'.format(b))
plt.plot(X,y_pred,color = '#A3E4D7',label = 'b = 0')
plt.legend()
plt.show()

# %%
loss_slope = -2 * np.sum(y - m*X.ravel() - b)
loss_slope
# Out:
# -1.674221072656735

# %%
step_size =  loss_slope * lr
step_size
# Out:
# -0.16742210726567353

# %%
b = b - step_size
b
# Out:
# 26.1178487334451

# %%
y_pred4 = ((78.35 * X) +b).reshape(4)

# %%
plt.figure(figsize=(15,15))
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color = 'red', label = 'OLS')
plt.plot(X,y_pred4,color = '#00a65a', label = 'b = {}'.format(b))
plt.plot(X,y_pred3,color = '#A3E4D7', label = 'b = {}'.format(b))
plt.plot(X,y_pred2,color = '#A3E4D7', label = 'b = {}'.format(b))
plt.plot(X,y_pred1,color = '#A3E4D7', label = 'b = {}'.format(b))
plt.plot(X,y_pred,color = '#A3E4D7',label = 'b = 0')
plt.legend()
plt.show()

# %%
b = -100
m = 78.35
lr = 0.1

epochs = 10

for i in range(epochs):
    loss_slope = -2 * np.sum(y - m*X.ravel() - b)
    b = b - (lr * loss_slope)

    y_pred = m * X + b

    plt.plot(X,y_pred)

plt.scatter(X,y)

# %%
m = 78.35
b = -100
lr = 0.001

epochs = 100

for i in range(epochs):
    loss_slope = -2 * np.sum(y -m*X.ravel() -b)
    b  = b - (lr * loss_slope)


    y_pred = m * X - b

    plt.plot(X,y_pred)

plt.scatter(X,y)

# %% [markdown]
# **Creating Class For GD Regressor**

# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt
import numpy as np

# %%
x,y = make_regression(n_samples = 100, n_features= 1, n_informative = 1, n_targets =1, noise  = 20 )

# %%
plt.scatter(x,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
lrm = LinearRegression()

# %%
lrm.fit(X,y)
print(lrm.coef_)
print(lrm.intercept_)
# Out:
# [4.29726508]
# 0.4364263261046493

# %%
m = 4.24

# %%
class GDRegressior:
    def __init__(self,learning_rate,epochs):
        self.m = 4.29
        self.lr = learning_rate
        self.b = -120
        self.epochs = epochs

    def fit(self,X,y):
        #calculate b using GD
        for i in range(epochs):
            loss_slope = -2 * np.sum(y - self.m*X.ravel() -self.b)
            self.b = b - (self.lr * loss_slope)
            print(loss_slope,self.b)
        print(self.b)

# %%
gd = GDRegressior(0.001,100)

# %%
gd.fit(X,y)
# Out:
# -24087.292746187042 -6.258132895838326
# -1338.9193253547107 -29.00650631667066
# -5888.594009521178 -24.45683163250419
# -4978.659072687884 -25.366766569337486
# -5160.6460600545415 -25.184779581970826
# -5124.24866258121 -25.22117697944416
# -5131.5281420758765 -25.213897499949493
# -5130.072246176944 -25.215353395848425
# -5130.36342535673 -25.21506221666864
# -5130.305189520773 -25.215120452504596
# -5130.316836687965 -25.2151088053374
# -5130.314507254524 -25.215111134770844
# -5130.314973141212 -25.215110668884158
# -5130.3148799638775 -25.215110762061492
# -5130.314898599344 -25.215110743426024
# -5130.314894872249 -25.21511074715312
# -5130.314895617669 -25.2151107464077
# -5130.314895468585 -25.215110746556782
# -5130.314895498402 -25.215110746526967
# -5130.314895492437 -25.215110746532932
# -5130.3148954936305 -25.21511074653174
# -5130.314895493393 -25.215110746531977
# -5130.31489549344 -25.215110746531927
# -5130.31489549343 -25.215110746531938
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -5130.314895493432 -25.215110746531934
# -25.215110746531934

# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import cross_val_score

# %%
X,y = make_regression(n_samples = 100, n_features = 1, n_informative = 1, noise = 20, random_state = 13)

# %%
plt.scatter(X,y)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
print(lr.coef_)
print(lr.intercept_)
# Out:
# [28.12597332]
# -2.2710144261783825

# %%
y_pred = lr.predict(X_test)
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.6345158782661012

# %%
lr.fit(X,y)
# Out:
# LinearRegression()

# %%
print(lr.coef_)
print(lr.intercept_)
# Out:
# [27.82809103]
# -2.29474455867698

# %%
np.mean(cross_val_score(lr,X,y,scoring = 'r2',cv = 10))
# Out:
# 0.6375011587464419

# %%
class GDregressior:

    def __init__(self,learning_rate,epochs):
        self.m = 100
        self.b = -120
        self.lr = learning_rate
        self.epochs = epochs


    def fit(self,X,y):
        #Calcualte the b using Gb
        for i in range(self.epochs):
            loss_slope_b = -2 * np.sum(y - self.m*X.ravel() - self.b)
            loss_slope_m = -2 * np.sum((y - self.m*X.ravel() - self.b) * X.ravel())
            
            self.m = self.m - (self.lr * loss_slope_m)
            self.b = self.b - (self.lr * loss_slope_b)

        print(self.m)
        print(self.b)


    def predict(self,X):
        return self.m*X -self.b

# %%
gd = GDregressior(0.001,50)

# %%
gd.fit(X,y)
# Out:
# 27.837060471820052
# -2.2991839308293196

# %%
gd.predict(X)
# Out:
# array([[-1.75316780e+01],
#        [-9.86966612e+00],
#        [-1.03319485e+01],
#        [ 2.88231873e+01],
#        [ 8.92044696e+00],
#        [ 2.62727770e+01],
#        [-4.47430366e+00],
#        [ 7.44753554e+00],
#        [-1.77713276e+01],
#        [-9.66788713e+00],
#        [ 5.83970079e+01],
#        [ 1.33572148e+01],
#        [ 8.08372658e+00],
#        [-4.17086912e+00],
#        [-1.90971329e+01],
#        [ 1.49137877e+01],
#        [ 2.01116728e+01],
#        [ 1.23075062e+01],
#        [-4.26606741e+01],
#        [ 5.09929334e+01],
#        [-1.96639513e+01],
#        [-1.19524194e+01],
#        [-2.35429399e+01],
#        [ 6.21595246e+01],
#        [-3.47282216e+00],
#        [-4.33283585e+01],
#        [-7.12695289e+00],
#        [-6.66779179e+00],
#        [-1.11007813e+01],
#        [-1.22641700e+01],
#        [ 2.23965689e+01],
#        [ 2.36198961e+01],
#        [ 1.49227631e+01],
#        [-3.28202171e+01],
#        [-5.85836762e+01],
#        [-3.06993911e+01],
#        [ 8.35239892e+00],
#        [ 3.93312966e+01],
#        [-2.79647558e+01],
#        [ 1.79508970e+01],
#        [-3.98139770e+01],
#        [ 2.23268048e+00],
#        [-5.44326342e+00],
#        [ 1.48763113e+01],
#        [ 3.54449186e+01],
#        [ 2.79745338e+01],
#        [ 2.49862614e+01],
#        [-1.49870656e+01],
#        [ 2.77350392e+01],
#        [ 3.39870298e+01],
#        [ 4.34614482e+01],
#        [-1.58243146e+01],
#        [-8.16532276e+00],
#        [-1.92650743e+01],
#        [ 1.62493731e+01],
#        [ 3.98844461e+01],
#        [ 2.25970072e+01],
#        [ 2.62446243e-02],
#        [-2.14776451e+01],
#        [ 1.52617331e+01],
#        [ 1.06034905e+00],
#        [ 6.97651371e-01],
#        [ 5.49875635e+01],
#        [-2.68010425e+01],
#        [ 1.80174995e+01],
#        [-5.12637590e+01],
#        [-1.89692759e+01],
#        [ 5.84293304e+00],
#        [ 1.55393989e+00],
#        [-1.74307272e+00],
#        [ 1.79671839e+01],
#        [ 1.11333008e+01],
#        [ 2.20906323e+01],
#        [ 2.32818242e+01],
#        [-8.00375972e+00],
#        [ 3.97428615e+01],
#        [ 1.71179059e+01],
#        [-2.50969593e+01],
#        [ 3.98877336e+01],
#        [-7.34933017e+00],
#        [ 1.66165874e+01],
#        [ 5.11823708e+00],
#        [-1.60041640e+01],
#        [ 2.54291550e+01],
#        [-6.53256809e+00],
#        [-2.49887716e+01],
#        [ 4.12498684e+01],
#        [ 1.75516190e+01],
#        [-1.24635722e+01],
#        [ 1.59636128e+01],
#        [ 1.20073753e+01],
#        [ 5.94679667e+01],
#        [ 1.91764779e+01],
#        [-8.40298790e+00],
#        [-5.18547741e+01],
#        [-6.46553937e+00],
#        [ 5.37869608e+01],
#        [-2.88924336e+01],
#        [-6.96153174e+00],
#        [-1.87860873e+01]])

# %%
gd.fit(X_train,y_train)
# Out:
# 28.125973288614077
# -2.2710144129477814

# %%
y_pred = gd.predict(X_test)
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.5957657667031735

# %% [markdown]
# ***Batch Gradient Descent***

# %%
from sklearn.datasets import load_diabetes

import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
X,y = load_diabetes(return_X_y = True)

# %%
print(X.shape)
print(y.shape)
# Out:
# (442, 10)
# (442,)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2,random_state = 2)

# %%
reg = LinearRegression()
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(reg.coef_)
print(reg.intercept_)
# Out:
# [  -9.15865318 -205.45432163  516.69374454  340.61999905 -895.5520019
#   561.22067904  153.89310954  126.73139688  861.12700152   52.42112238]
# 151.88331005254167

# %%
y_pred = reg.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.4399338661568968

# %%
class GDRegressior:

    def __init__(self,learning_rate=0,epochs = 100):
        self.coef_ = None
        self.intercept_ = None
        self.lr = learning_rate
        self.epochs = epochs


    def fit(self,X_train,y_train):
        #init you coef
        self.intercept_ = 0
        self.coef_ = np.ones(X_train.shape[1])


        for i in range(int(self.epochs):
            # update all the coef and intercept
            #vactorization
            y_hat = np.dot(X_train,self.coef_) + self.intercept_
            #print("Shape of Y_hat ",y_hat.shape)   
            intercept_der = -2 * np.mean(y_train - y_hat)
            self.intercept_ = self.intercept_ - (self.lr * intercept_der)
            
            coef_der = -2 * np.dot((y_train - y_hat),X_train)/X_train.shape[0]
            self.coef_ = self.coef_ - (self.lr * coef_der)
            
        
        print(self.coef_,self.intercept_)


    def predict(self,X_test):
        return np.dot(X_test,self.coef_) + self.intercept_

# %%
gdr = GDRegressior(learning_rate = 0.5, epochs = 1000 )

# %%
gdr.fit(X_train,y_train)
# Out:
# [  14.38990585 -173.7235727   491.54898524  323.91524824  -39.32648042
#  -116.01061213 -194.04077415  103.38135565  451.63448787   97.57218278] 152.01351687661833

# %%
y_pred = gdr.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.4534503034722803

# %% [markdown]
# ***Stochastic Gradient Descent***

# %%
from sklearn.datasets import load_diabetes

import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
import time

# %%
X,y = load_diabetes(return_X_y = True)

# %%
print(X.shape)
print(y.shape)
# Out:
# (442, 10)
# (442,)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2,random_state = 2)

# %%
reg = LinearRegression()
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(reg.coef_)
print(reg.intercept_)
# Out:
# [  -9.15865318 -205.45432163  516.69374454  340.61999905 -895.5520019
#   561.22067904  153.89310954  126.73139688  861.12700152   52.42112238]
# 151.88331005254167

# %%
y_pred = reg.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.4399338661568968

# %%
class SDRegressior:

    def __init__(self,learning_rate=0,epochs = 100):
        self.coef_ = None
        self.intercept_ = None
        self.lr = learning_rate
        self.epochs = epochs


    def fit(self,X_train,y_train):
        #init you coef
        self.intercept_ = 0
        self.coef_ = np.ones(X_train.shape[1])
                             
        for i in range(self.epochs):
            for j in range(X_train.shape[0]):
                idx = np.random.randint(0,X_train.shape[0])
                
                y_hat = np.dot(X_train[idx],self.coef_) + self.intercept_

                intercept_der = -2 * np.mean(y_train[idx] - y_hat)
                self.intercept_ = self.intercept_ - (self.lr * intercept_der)

                coef_der = -2 * np.dot((y_train[idx] - y_hat),X_train[idx])
                self.coef_ = self.coef_ - (self.lr * coef_der)
                
                             
        print(self.intercept_,self.coef_)


    def predict(self,X_test):
        return np.dot(X_test,self.coef_) + self.intercept_

# %%
sgd = SGDRegressior(learning_rate = 0.01, epochs = 50)

# %%
start = time.time()
sgd.fit(X_train,y_train)
print(time.time()-start)
# Out:
# [  49.42225921  -69.05185492  355.63140336  258.55216036   15.15091878
#   -29.33741486 -177.76922429  131.04045168  320.63787626  120.93934155] 149.77885224338002
# 0.5168063640594482

# %%
y_pred = sgd.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.43201316439118065

# %% [markdown]
# ***SGDRegressor Class***

# %%
from sklearn.linear_model import SGDRegressor

# %%
dfg = SGDRegressor(max_iter = 100, learning_rate = 'constant', eta0 = 0.01)

# %%
dfg.fit(X_train,y_train)
# Out:
# SGDRegressor(learning_rate='constant', max_iter=100)

# %%
y_pred = dfg.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.4313225920610608

# %% [markdown]
# ***Mini-Batch Gradient Descent***

# %%
from sklearn.datasets import load_diabetes

import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
X,y = load_diabetes(return_X_y=True)

# %%
print(X.shape)
print(y.shape)
# Out:
# (442, 10)
# (442,)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
reg = LinearRegression()
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(reg.coef_)
print(reg.intercept_)
# Out:
# [  -9.15865318 -205.45432163  516.69374454  340.61999905 -895.5520019
#   561.22067904  153.89310954  126.73139688  861.12700152   52.42112238]
# 151.88331005254167

# %%
y_pred = reg.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.4399338661568968

# %%
import random

class MBGDRegressor:
    
    def __init__(self,batch_size,learning_rate=0.01,epochs=100):
        
        self.coef_ = None
        self.intercept_ = None
        self.lr = learning_rate
        self.epochs = epochs
        self.batch_size = batch_size
        
    def fit(self,X_train,y_train):
        # init your coefs
        self.intercept_ = 0
        self.coef_ = np.ones(X_train.shape[1])
        
        for i in range(self.epochs):
            
            for j in range(int(X_train.shape[0]/self.batch_size)):
                
                idx = random.sample(range(X_train.shape[0]),self.batch_size)
                
                y_hat = np.dot(X_train[idx],self.coef_) + self.intercept_
                #print("Shape of y_hat",y_hat.shape)
                intercept_der = -2 * np.mean(y_train[idx] - y_hat)
                self.intercept_ = self.intercept_ - (self.lr * intercept_der)

                coef_der = -2 * np.dot((y_train[idx] - y_hat),X_train[idx])
                self.coef_ = self.coef_ - (self.lr * coef_der)
        
        print(self.intercept_,self.coef_)
    
    def predict(self,X_test):
        return np.dot(X_test,self.coef_) + self.intercept_

# %%
mbr = MBGDRegressor(batch_size=int(X_train.shape[0]/50),learning_rate=0.01,epochs=100)

# %%
mbr.fit(X_train,y_train)
# Out:
# 150.84845452225332 [  35.44977098 -143.27639254  449.02560728  312.46374763  -19.59844418
#   -87.96289203 -186.98573478  109.53553982  405.23294526  116.91995484]

# %%
y_pred = mbr.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.451663351568927

# %%
from sklearn.linear_model import SGDRegressor

# %%
sgd = SGDRegressor(learning_rate='constant',eta0=0.1)

# %%
batch_size = 35

for i in range(100):
    
    idx = random.sample(range(X_train.shape[0]),batch_size)
    sgd.partial_fit(X_train[idx],y_train[idx])

# %%
sgd.coef_
# Out:
# array([  59.89979478,  -61.2358042 ,  362.12788338,  243.92798046,
#          22.24075137,  -21.021722  , -165.77870122,  122.75727547,
#         312.76868633,  125.74829798])

# %%
sgd.intercept_
# Out:
# array([163.13382207])

# %%
y_pred = sgd.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.4103157026113585
